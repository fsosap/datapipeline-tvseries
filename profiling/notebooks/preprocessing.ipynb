# %%
import json         as json
import pandas       as pd
import sys
sys.path.insert(0, '../../src/')
import json_reader as jsonrd

from ydata_profiling import ProfileReport
from pandas import json_normalize

pd.options.display.max_columns = None

# %%
file_path = "resources/2022-12-01.json"
data = jsonrd.read_json_from_path(file_path)
df = jsonrd.json_to_dataframe(data)

df.head()
# Out:
#         id                                                url      name  \
# 0  2450906  https://www.tvmaze.com/episodes/2450906/hocu-v...  Серия 87
# 1  2450907  https://www.tvmaze.com/episodes/2450907/hocu-v...  Серия 88
# 2  2438114  https://www.tvmaze.com/episodes/2438114/restor...  Серия 15
# 3  2438115  https://www.tvmaze.com/episodes/2438115/restor...  Серия 16
# 4  2413779  https://www.tvmaze.com/episodes/2413779/alisa-...   8 серия
#
#    season  number     type     airdate airtime                   airstamp  \
# 0       2    87.0  regular  2022-12-01          2022-12-01T00:00:00+00:00
# 1       2    88.0  regular  2022-12-01          2022-12-01T00:00:00+00:00
# 2       2     5.0  regular  2022-12-01          2022-12-01T00:00:00+00:00
# 3       2     6.0  regular  2022-12-01          2022-12-01T00:00:00+00:00
# 4       1     8.0  regular  2022-12-01   12:00  2022-12-01T00:00:00+00:00
#
#    runtime  image summary  rating.average  \
# ...

# %%
df_cols = df.columns
df_cols
# Out:
# Index(['id', 'url', 'name', 'season', 'number', 'type', 'airdate', 'airtime',
#        'airstamp', 'runtime', 'image', 'summary', 'rating.average',
#        '_links.self.href', '_links.show.href', '_embedded.show.id',
#        '_embedded.show.url', '_embedded.show.name', '_embedded.show.type',
#        '_embedded.show.language', '_embedded.show.genres',
#        '_embedded.show.status', '_embedded.show.runtime',
#        '_embedded.show.averageRuntime', '_embedded.show.premiered',
#        '_embedded.show.ended', '_embedded.show.officialSite',
#        '_embedded.show.schedule.time', '_embedded.show.schedule.days',
#        '_embedded.show.rating.average', '_embedded.show.weight',
#        '_embedded.show.network', '_embedded.show.webChannel.id',
#        '_embedded.show.webChannel.name',
#        '_embedded.show.webChannel.country.name',
#        '_embedded.show.webChannel.country.code',
#        '_embedded.show.webChannel.country.timezone',
# ...

# %%
df.describe()
# Out:
#                  id       season      number     runtime  image  \
# count  1.710000e+02   171.000000  169.000000  160.000000    0.0
# mean   2.444654e+06    62.017544   18.940828   36.506250    NaN
# std    3.817806e+04   341.196622   39.999361   25.956664    NaN
# min    2.323161e+06     1.000000    1.000000    2.000000    NaN
# 25%    2.427729e+06     1.000000    3.000000   23.000000    NaN
# 50%    2.438318e+06     1.000000    6.000000   31.000000    NaN
# 75%    2.452720e+06     3.000000   12.000000   47.000000    NaN
# max    2.603381e+06  2022.000000  265.000000  240.000000    NaN
#
#        rating.average  _embedded.show.id  _embedded.show.runtime  \
# count       32.000000         171.000000               62.000000
# mean         6.984375       56436.888889               36.741935
# std          1.031475       15217.480968               37.928723
# min          3.300000          81.000000                2.000000
# ...

# %%
# aknowledge some full NaN columns leading to completely empty columns, those are dropped at the dataframe's copy named no_nan_df
no_nan_df = df.dropna(axis=1, how="all")
no_nan_df.describe()
# Out:
#                  id       season      number     runtime  rating.average  \
# count  1.710000e+02   171.000000  169.000000  160.000000       32.000000
# mean   2.444654e+06    62.017544   18.940828   36.506250        6.984375
# std    3.817806e+04   341.196622   39.999361   25.956664        1.031475
# min    2.323161e+06     1.000000    1.000000    2.000000        3.300000
# 25%    2.427729e+06     1.000000    3.000000   23.000000        6.575000
# 50%    2.438318e+06     1.000000    6.000000   31.000000        6.900000
# 75%    2.452720e+06     3.000000   12.000000   47.000000        7.200000
# max    2.603381e+06  2022.000000  265.000000  240.000000       10.000000
#
#        _embedded.show.id  _embedded.show.runtime  \
# count         171.000000               62.000000
# mean        56436.888889               36.741935
# std         15217.480968               37.928723
# min            81.000000                2.000000
# 25%         54367.500000               14.250000
# ...

# %%
no_nan_df_cols = no_nan_df.columns
no_nan_df_cols
# Out:
# Index(['id', 'url', 'name', 'season', 'number', 'type', 'airdate', 'airtime',
#        'airstamp', 'runtime', 'summary', 'rating.average', '_links.self.href',
#        '_links.show.href', '_embedded.show.id', '_embedded.show.url',
#        '_embedded.show.name', '_embedded.show.type', '_embedded.show.language',
#        '_embedded.show.genres', '_embedded.show.status',
#        '_embedded.show.runtime', '_embedded.show.averageRuntime',
#        '_embedded.show.premiered', '_embedded.show.ended',
#        '_embedded.show.officialSite', '_embedded.show.schedule.time',
#        '_embedded.show.schedule.days', '_embedded.show.rating.average',
#        '_embedded.show.weight', '_embedded.show.webChannel.id',
#        '_embedded.show.webChannel.name',
#        '_embedded.show.webChannel.country.name',
#        '_embedded.show.webChannel.country.code',
#        '_embedded.show.webChannel.country.timezone',
#        '_embedded.show.webChannel.officialSite',
# ...

# %%
# which columns were completely emplty?
df_cols.difference(no_nan_df_cols)
# Out:
# Index(['_embedded.show.dvdCountry', '_embedded.show.image',
#        '_embedded.show.network', '_embedded.show.webChannel',
#        '_embedded.show.webChannel.country', 'image'],
#       dtype='object')

# %%
no_nan_df
# Out:
#           id                                                url  \
# 0    2450906  https://www.tvmaze.com/episodes/2450906/hocu-v...
# 1    2450907  https://www.tvmaze.com/episodes/2450907/hocu-v...
# 2    2438114  https://www.tvmaze.com/episodes/2438114/restor...
# 3    2438115  https://www.tvmaze.com/episodes/2438115/restor...
# 4    2413779  https://www.tvmaze.com/episodes/2413779/alisa-...
# ..       ...                                                ...
# 166  2501911  https://www.tvmaze.com/episodes/2501911/infoma...
# 167  2434905  https://www.tvmaze.com/episodes/2434905/puppy-...
# 168  2436366  https://www.tvmaze.com/episodes/2436366/de-fer...
# 169  2439198  https://www.tvmaze.com/episodes/2439198/de-fer...
# 170  2434906  https://www.tvmaze.com/episodes/2434906/puppy-...
#
#                                   name  season  number                   type  \
# 0                             Серия 87       2    87.0                regular
# ...

# %%
no_nan_df.describe(include="all")
# Out:
#                   id                                                url  \
# count   1.710000e+02                                                171
# unique           NaN                                                171
# top              NaN  https://www.tvmaze.com/episodes/2450906/hocu-v...
# freq             NaN                                                  1
# mean    2.444654e+06                                                NaN
# std     3.817806e+04                                                NaN
# min     2.323161e+06                                                NaN
# 25%     2.427729e+06                                                NaN
# 50%     2.438318e+06                                                NaN
# 75%     2.452720e+06                                                NaN
# max     2.603381e+06                                                NaN
#
#            name       season      number     type     airdate airtime  \
# ...

# %%
# evaluate distribution for column type
df["type"].value_counts()
# Out:
# type
# regular                  169
# significant_special        1
# insignificant_special      1
# Name: count, dtype: int64

# %%
# evaluate distribution for column type
df["_embedded.show.type"].value_counts()
# Out:
# _embedded.show.type
# Scripted       97
# Documentary    20
# Animation      18
# Reality        17
# Talk Show       9
# Game Show       3
# News            3
# Sports          3
# Variety         1
# Name: count, dtype: int64

# %%
# automated tool for data-profiling to get more insights
ProfileReport(no_nan_df, title="TVshows dataset profiling-report", html={'style':{'full_width':True}}).to_file("../tvseries-profiling.html")
# Out:
# /Users/work/programming/datapipeline-tvseries/env/lib/python3.9/site-packages/ydata_profiling/utils/dataframe.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"index": "df_index"}, inplace=True)
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# /Users/work/programming/datapipeline-tvseries/env/lib/python3.9/site-packages/scipy/stats/_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
